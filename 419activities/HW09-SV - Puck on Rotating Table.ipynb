# %% [markdown]
# # *[HW09] Puck on Rotating Table [Taylor Problem 9.24]*
# We will be learning how to use python to facilitate calculations and study complex physical situations computationally.
#
# **Step 1** Save a copy of this file in your PSU google-drive.
#
# **Step 2** In your copy, hover your mouse over the [] brackets and a "play arrow" will appear - click it to run that bit of code.
#
# **Step 3** if you see,
#
# ```
# ''' Write code here'''
# ```
# written in <font color="orange">orange</font> - this is the place where you will have to add your own code using the variables explained in <font color="green">green</font>.

# %% [markdown]
# Consider a frictionless puck on a horizontal turntable rotating counterclockwise with angular velocity `Omega = 1` ($\Omega = 1$); we'll ignore units.
#
# The equations of motion describing the puck are given by [Taylor Problem 9.20]:
#
# \begin{align}
#   x &= +(x_0 + v_{0x}t)\cos(\Omega t)+(v_{0y}+\Omega x_0)t\sin(\Omega t) \\
#   y &= -(x_0 +v_{0x}t)\sin(\Omega t)+(v_{0y}+\Omega x_0)t \cos(\Omega t)
# \end{align}
#
# 🎯 **Assignment:**
# * **(Section A):** Setup code to plot the trajectory $y(x)$
# * **(Section B):** Create six plots with different initial conditions.
#
# 💡 Refer to *[PRE06] Graphing with for-loops* for creating subplots.

# %% [markdown]
# ## Section A: One plot

# %% [markdown]
# 👉 Fill in the missing code wherever you see `'''Write code here'''`

# %%
# (0) Import libraries
import numpy as np
import matplotlib.pyplot as plt

# (i) Define time array and angular velocity
t=np.linspace(0,10,100)
Omega=1

# (ii) Initial conditions x0, v0x, v0y
x0 = 1
v0x = 0
v0y = 1

# (iii) Equations of motion for 'x' and 'y'
'''Write code here'''

# (iv) Plot
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Hockey puck trajectories')
plt.show()

# %% [markdown]
# ## Section B: Six plots

# %% [markdown]
# Now that the basic code works, we create an array of initial velocity values $\{(v_{0x},v_{0y})\}$.
#
# Now, cycle through those values in a for-loop to generate six plots. Visualize this in two different ways:
# 1. Superimpose six plots on the same graph
# 2. Create six subplots.
#
# 💡 Refer to *[PRE06] Graphing with for-loops* for creating subplots.
#
# 👉 Fill in the missing code wherever you see `'''Write code here'''`

# %% [markdown]
# #### B0 Create array of initial conditions
#
# Please make 6 plots with $v_0=(v_{0x},v_{0y})$
#
# *   $v_0$=(0,1)
# *   $v_0$=(0,0)
# *   $v_0$= (0,-1)
# *   $v_0$= (-0.5,0.5)
# *   $v_0$=(-0.7,-0.7)
# *   $v_0$=(0,-0.1)

# %%
v0x_list = np.array([0, 0, 0, -0.5, -0.7, 0])
v0y_list = np.array([1, 0, -1, -0.5, -0.7, -0.1])

print(f"v0x values: {v0x_list}")
print(f"v0y values: {v0y_list}")

# %% [markdown]
# #### B1 Superimpose six plots on the same graph (include labels)

# %%
# Make one graph with six curves (use a for-loop)
'''Write code here'''

# %% [markdown]
# #### B2 Create six subplots (include labels)

# %%
# (0) Create a figure and a 2x3 grid of subplots

fig, graphs = plt.subplots(2, 3, figsize=(10, 8)) # Adjust figsize as needed

# (i) Flatten array
graphs = graphs.flatten()

# (ii) Create subplots (use a for-loop)
'''Write code here'''



# Plot (this is outside the for-loop)
plt.tight_layout() # Adjusts subplot parameters for a tight layout
plt.show()

# %% [markdown]
# #### B3 Write about it

# %% [markdown]
# 👉 Write a few sentences describing your observations and how the trajectories depend on the initial velocities.

# %% [markdown]
# `Write answer here`

# %% [markdown]
# # Submission instructions

# %% [markdown]
# ## Submitting as a **PDF**
#
#
# To export as a PDF, in the toolbar navigate to File>>Print (or press CTRL+P), and then "print to PDF".
#
# Submit the <font color="red">PDF</font> along with any other work (e.g. the paper copy of the recitation) to Canvas.
